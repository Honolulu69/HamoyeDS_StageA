# %%
#Importing libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
# Loading the dataset
energy = pd.read_csv('energydata_complete.csv')

# %%
energy.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#Question 17
from sklearn import metrics
x = energy.iloc[:, 5].values
y = energy.iloc[:, 13].values

x = x.reshape(-1,1)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_train = x_train.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
logm = LinearRegression()
logm.fit(x_train, y_train)
y_pred = logm.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("The root mean squared error is", round(rmse, 3))
# Out:
# The root mean squared error is 3.63

# %%
# Question 18 -Quiz Instructions
from sklearn.preprocessing import MinMaxScaler
new_energy_ds  = energy.drop(columns=['date','lights'])
Minmax = MinMaxScaler()
Minmax.fit(new_energy_ds)
normalized_ds = pd.DataFrame(Minmax.fit_transform(new_energy_ds), columns = new_energy_ds.columns)

# %%
# Target and the training variables selections
output = normalized_ds['Appliances']
features = normalized_ds.drop(columns=['Appliances'])

# %%
#Dataset Splitting
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, output, train_size = 0.7, random_state=42)

# %%
#Question 18
logm.fit(x_train, y_train)

y_pred = logm.predict(x_train)

mean_abs_error = mean_absolute_error(y_train, y_pred)
print("the mean absolute error is", round(mean_abs_error, 3))
# Out:
# the mean absolute error is 0.05

# %%
#Question 19
logm.fit(x_train, y_train)

y_pred = logm.predict(x_train)

rmse = np.sqrt(mean_squared_error(y_train, y_pred))
print("the root mean squared error is ", round(rmse, 3))
# Out:
# the root mean squared error is  0.089

# %%
#Question 20
logm.fit(x_train, y_train)

y_pred = logm.predict(x_test)

from sklearn.metrics import mean_absolute_error
mean_abs_error = mean_absolute_error(y_test, y_pred)
print("the mean absolute error  is", round(mean_abs_error, 3))
# Out:
# the mean absolute error  is 0.05

# %%
#Question 21
logm.fit(x_train, y_train)

y_pred = logm.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("the root mean squared error is ", round(rmse, 3))
# Out:
# the root mean squared error is  0.088

# %%
#Question 22 - No overfitting observed

# Weights on Lin Reg Model before Penalization
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_model_weights = get_weights_df(logm, x_train, 'Linear_Model_Weight')

linear_model_weights.sort_values(by='Linear_Model_Weight', ascending=True)
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
# Question 23

# Instantiating ridge model with default alpha value
ridge = Ridge()

ridge.fit(x_train, y_train)

pred1 = ridge.predict(x_test)

ridge_rmse = round(np.sqrt(metrics.mean_squared_error(y_test,pred1)),3)

print(f'The RMSE score for the rigde model with default aplha value when evaluated on the test set is: {ridge_rmse}')
# Out:
# The RMSE score for the rigde model with default aplha value when evaluated on the test set is: 0.088

# %%
#Question 24

# Initiating a lasso regressor with a default alpha value
lasso_reg = Lasso()

lasso_reg.fit(x_train, y_train)

lasso_preds = lasso_reg.predict(x_test)

def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

non_zero_weights = lasso_weights_df[lasso_weights_df['Lasso_weight'] != 0]

# non_zero feature weights 
print(non_zero_weights)
# Out:
# Empty DataFrame
# Columns: [Features, Lasso_weight]
# Index: []

# %%
lasso_weights_df['Lasso_weight'].unique()
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0            T1           0.0
# 1     Tdewpoint           0.0
# 2    Visibility           0.0
# 3     Windspeed           0.0
# 4        RH_out          -0.0
# 5   Press_mm_hg          -0.0
# 6         T_out           0.0
# 7          RH_9          -0.0
# 8            T9           0.0
# 9          RH_8          -0.0
# 10           T8           0.0
# 11         RH_7          -0.0
# 12           T7           0.0
# 13         RH_6          -0.0
# 14           T6           0.0
# 15         RH_5           0.0
# 16           T5           0.0
# 17         RH_4           0.0
# 18           T4           0.0
# 19         RH_3           0.0
# 20           T3           0.0
# 21         RH_2          -0.0
# 22           T2           0.0
# 23         RH_1           0.0
# 24          rv1          -0.0
# 25          rv2          -0.0

# %%
#Question 25
RMSE_new = round(np.sqrt(metrics.mean_squared_error(y_test,lasso_preds)),3)
RMSE_new
# Out:
# 0.095
